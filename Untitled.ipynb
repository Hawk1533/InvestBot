# %%
import json
token_prod = 't.7NtUAgpCETQULN320S0FRJa5brFuWiMljw3iO39L1O1km1b5kmHNwESb1zZMU_4mWQ_t_AbCtsIrEd0Rx-uCVA'
token_sandbox = 't.rxYo9fDNVFHA52jYHq9pOl4bWaQV5C-AqJLg5KxExzPyk8SLIFWcPorKjrzel2w53S9AZsJRArSpRqZxiZAG9A'

from openapi_client import openapi
from datetime import datetime, timedelta
from pytz import timezone
import seaborn as sns
from matplotlib import pyplot as plt
from datetime import *
from datetime import timedelta
from dateutil.tz import tzutc

import random
import time
from threading import Thread

token = token_sandbox
client = openapi.sandbox_api_client(token)
client.sandbox.sandbox_clear_post()
client.sandbox.sandbox_register_post()
client.sandbox.sandbox_currencies_balance_post(sandbox_set_currency_balance_request={"currency": "USD", "balance": 1000})
# Out:
# {'payload': {}, 'status': 'Ok', 'tracking_id': 'a9fcf4360334be6e'}

# %%
str(datetime.now())
# Out:
# '2019-11-08 00:36:36.712616'

# %%
stocks
# Out:
# {'payload': {'instruments': [{'currency': 'USD',
#                               'figi': 'BBG000BR37X2',
#                               'isin': 'US7433151039',
#                               'lot': 1,
#                               'min_price_increment': 0.01,
#                               'name': 'Progressive',
#                               'ticker': 'PGR'},
#                              {'currency': 'USD',
#                               'figi': 'BBG000B9ZV28',
#                               'isin': 'US0234361089',
#                               'lot': 1,
#                               'min_price_increment': 0.01,
#                               'name': 'Amedisys Inc',
#                               'ticker': 'AMED'},
#                              {'currency': 'USD',
#                               'figi': 'BBG000HLJ7M4',
#                               'isin': 'US45867G1013',
#                               'lot': 1,
# ...

# %%
for i in range(5000):
    stocks = min15_dif('BBG000BR37X2')
    #print (stocks)
# Out:
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# Ok
# ...

# %%
stocks = client.market.market_stocks_get().to_dict()['payload']['instruments']
figi = {}
for stock in stocks:
    figi[stock['name']] = stock['figi']
figi
# Out:
# {'Progressive': 'BBG000BR37X2',
#  'Amedisys Inc': 'BBG000B9ZV28',
#  'InterDigItal Inc': 'BBG000HLJ7M4',
#  'Xylem': 'BBG001D8R5D0',
#  'Belden Inc': 'BBG000Q4XNV1',
#  'RH': 'BBG002293PJ4',
#  'Starbucks Corporation': 'BBG000CTQBF3',
#  'MTS Systems Corp': 'BBG000BPL8G3',
#  'Seattle Genetics Inc': 'BBG000BH0FR6',
#  "Sotheby's": 'BBG000BD6GP9',
#  'Башнефть': 'BBG004S68758',
#  'Navient': 'BBG004MN1R41',
#  'Maxim Integrated Products Inc': 'BBG000BPNP00',
#  'Winnebago Industries Inc': 'BBG000BWS3F3',
#  'Caterpillar': 'BBG000BF0K17',
#  'Ligand Pharmaceuticals Inc': 'BBG000BKF014',
#  'Westlake Chemical': 'BBG000PXZFW2',
#  'United Technologies': 'BBG000BW8S60',
#  'Agilent Technologies': 'BBG000C2V3D6',
#  'Axon Enterprise Inc': 'BBG000BHJWG1',
#  'Trex Co Inc': 'BBG000BTGKK9',
#  'Rockwell Automation': 'BBG000BBCDZ2',
#  'Biglari Holdings Inc': 'BBG00JPRDQH1',
#  'Вторая генерирующая компания оптового рынка электроэнергии': 'BBG000RK52V1',
# ...

# %%
len(figi)
# Out:
# 1177

# %%
time_shift  = timedelta(hours=12)

# %%
a = day_dif
a.__name__
# Out:
# 'day_dif'

# %%
(datetime.now() - timedelta(minutes=155) - time_shift).isoformat()+'+03:00'
# Out:
# '2019-11-05T14:05:05.621355+03:00'

# %%
(datetime.now() - time_shift).isoformat()+'+03:00'
# Out:
# '2019-11-05T16:40:08.672956+03:00'

# %%
from datetime import datetime
time_shift = timedelta(hours=4)
ans = client.market.market_candles_get(figi = 'BBG000BR37X2', 
                                 _from = (datetime.now() - timedelta(days=1) - time_shift).isoformat()+'+03:00',
                                 to = (datetime.now() - time_shift).isoformat()+'+03:00' ,
                                 interval = '15min')
ans
#sorted(ans.to_dict()['payload']['candles'], key=lambda k: k['time'].timestamp()) 
#SORTED(ANS.TO_DICT()['PAYLOAD']['CANDLES'], KEY=LAMBDA K: K['TIME'].TIMESTAMP())
# Out:
# {'payload': {'candles': [{'c': 69.36,
#                           'figi': 'BBG000BR37X2',
#                           'h': 69.4,
#                           'interval': '15min',
#                           'l': 69.36,
#                           'o': 69.38,
#                           'time': datetime.datetime(2019, 11, 4, 18, 15, tzinfo=tzutc()),
#                           'v': 8355},
#                          {'c': 69.36,
#                           'figi': 'BBG000BR37X2',
#                           'h': 69.38,
#                           'interval': '15min',
#                           'l': 69.31,
#                           'o': 69.36,
#                           'time': datetime.datetime(2019, 11, 4, 18, 30, tzinfo=tzutc()),
#                           'v': 12779},
#                          {'c': 69.34,
#                           'figi': 'BBG000BR37X2',
#                           'h': 69.37,
#                           'interval': '15min',
# ...

# %%
min15_dif('BBG000BR37X2')
# Out:
# 0

# %%
def min15_dif(figi):
    ans = client.market.market_candles_get(figi = figi, 
                                     _from = (datetime.now() - timedelta(minutes=20) - time_shift).isoformat()+'+03:00',
                                     to = (datetime.now() - time_shift).isoformat()+'+03:00' ,
                                     interval = '15min')
    try:
        print (ans.status)
        ans = ans.to_dict()['payload']['candles'][-1]
        print('min 15 requesting')
        return (ans['c'] - ans['o'])/ans['o'] * 100
    except:
        return 0

# %%
def day_dif(figi):
    ans = client.market.market_candles_get(figi = figi, 
                                     _from = (datetime.now() - timedelta(days=7) - timedelta(hours=7)).isoformat()+'+03:00',
                                     to = datetime.now().isoformat()+'+03:00' ,
                                     interval = 'day')


    ans = ans.to_dict()['payload']['candles'][0]
    return (ans['c'] - ans['o'])/ans['o'] * 100

def min1_dif(figi):
    ans = client.market.market_candles_get(figi = figi, 
                                     _from = (datetime.now() - timedelta(minutes=2)).isoformat()+'+03:00',
                                     to = datetime.now().isoformat()+'+03:00' ,
                                     interval = '1min')

    print(ans)
    ans = ans.to_dict()['payload']['candles'][0]
    return (ans['c'] - ans['o'])/ans['o'] * 100

def plotans(ans):
    ans = ans.to_dict()['payload']['candles']
    val = []
    time = []
    for elem in ans:
        val.append(elem['c'])
        time.append(elem['time'].timestamp())

    sns.lineplot(time, val)
    plt.show()

#min1_dif(figi = 'BBG006L8G4H1')

# %%
figi = {'yandex': 'BBG006L8G4H1'}
for key in figi:
    print (figi[key])
# Out:
# BBG006L8G4H1

# %%
f = min1_dif
f(figi = 'BBG006L8G4H1')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-99-0f647dfc6058> in <module>()
#       1 f = min1_dif
# ----> 2 f(figi = 'BBG006L8G4H1')
#
# <ipython-input-97-435c4ec6f65f> in min1_dif(figi)
#      16
#      17
# ---> 18     ans = ans.to_dict()['payload']['candles'][0]
#      19     return (ans['c'] - ans['o'])/ans['o'] * 100
#      20
#
# IndexError: list index out of range

# %%
def test():
    print('a')

# %%
funcs = [test]
intervals = [1]

class MyThread(Thread):
    def __init__(self, interval, func):
        Thread.__init__(self)
        self.interval = interval
        self.func = func
    
    def run(self):
        while(1):
            time.sleep(self.interval)
            self.func()
    
def create_threads():
    for i in range(len(funcs)):
        name = "Thread #%s" % (i+1)
        my_thread = MyThread(intervals[i], funcs[i])
        my_thread.start()

# %%
if __name__ == "__main__":
    create_threads()

# %%
create_threads();

# %%
d = {}
d['ya'] = datetime.now() + timedelta(minutes = 10)
d
# Out:
# {'ya': datetime.datetime(2019, 11, 8, 1, 22, 52, 715516)}

# %%
old = []
for key in d:
    if d[key] <= datetime.now():
        old.append(key)
old
# Out:
# []
